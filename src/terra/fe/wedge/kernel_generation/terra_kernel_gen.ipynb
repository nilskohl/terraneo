# %%
from sympy import ccode
import os, sys
from integrands import *
from kernel_helpers import *

local_subdomain_id, x_cell, y_cell, r_cell = sp.symbols("local_subdomain_id x_cell y_cell r_cell")

def flattened_cse(M, prefix):
    
    exprs = M.tolist()
    exprs_flat = [item for row in exprs for item in row]

    return sp.cse(exprs=exprs_flat, symbols=numbered_symbols(prefix=prefix))

def replace_matrix(matrix, prefix):
    replace_assignments = []
    replaced_matrix = []
    for i in range(3):
        for j in range(3):
            tmp_ij = sp.symbols(f"{prefix}_{i}_{j}")
            replaced_matrix.append(tmp_ij)
            replace_assignments.append((tmp_ij, matrix[i,j]))
    replaced_matrix = sp.Matrix(3, 3, replaced_matrix)
    return replace_assignments, replaced_matrix
    
kernel = []

### initial decls and loads
quad, wedge, lat, wedge_assignments = make_wedge_surface_physical_coord_assignments(local_subdomain_id, x_cell, y_cell)
rads, rad_assignments = make_rad_assignments(local_subdomain_id, r_cell)
num_qps, qps, qws, qp_assignments = make_quad_assignments(quad_points_1x1, quad_weights_1x1)
srcs, src_assignments = make_extract_local_wedge_scalar_assignments(local_subdomain_id, x_cell, y_cell, r_cell)
#make_hex_assignments(local_subdomain_id, x_cell, y_cell, r_cell)
kernel += wedge_assignments
kernel += rad_assignments
kernel += qp_assignments
kernel += src_assignments

qp_data = quad_points_1x1
qw_data = quad_weights_1x1

num_wedges_per_hex_cell = 2
num_nodes_per_wedge_surface = 3
num_nodes_per_wedge = 6
dim = 3
dsts = []
for qi in range(num_qps):
    for w in range(num_wedges_per_hex_cell):
        ### Jacobian
        J = jac_from_array(wedge[w], rads[0], rads[1], qp_data[qi])

        # 1. first CSE
        J_cse_assignments, J_cse_exprs = flattened_cse(J, f"w{w}_tmpcse_J_")
        kernel += J_cse_assignments

        # 2. replace entries with tmp symbols to speed up inversion
        J_cse = sp.Matrix(3, 3, J_cse_exprs)
        J_cse_replaced_assignments, J_cse_replaced = replace_matrix(J_cse, f"w{w}_J")
        kernel += J_cse_replaced_assignments

        # 3. invert
        J_invT = J_cse_replaced.inv().transpose()

        # 4. second CSE after inversion
        J_invT_replacements, J_invT_reduced_exprs = flattened_cse(J_invT, f"w{w}_tmpcse_J_invT_")
        kernel += J_invT_replacements
        J_invT_cse = sp.Matrix(3, 3, J_invT_reduced_exprs)
        J_invT_cse_assignments, J_invT_cse_replaced = replace_matrix(J_invT_cse, f"w{w}_J_invT_cse")
        kernel += J_invT_cse_assignments
      
        # 5. compute abs determinant + CSE
        J_abs_det = abs(J_cse_replaced.det())
        J_absdet_replacements, J_absdet_reduced_exprs = sp.cse(exprs=J_abs_det,symbols=numbered_symbols(prefix=f"w{w}_tmpcse_absdet_"))
        kernel += J_absdet_replacements
        absdet = sp.symbols("absdet") 
        kernel.append((absdet, J_absdet_reduced_exprs[0]))
        
        # local mat CSE
        local_mat_exprs = []
        for i in range(num_nodes_per_wedge):
            for j in range(num_nodes_per_wedge):
                local_mat_ij = sp.symbols(f"w{w}_local_mat_{i}_{j}")
               
                grad_i = J_invT_cse * grad_shape_vec(i, qp_data[qi])
                grad_j = J_invT_cse * grad_shape_vec(j, qp_data[qi])
                tmp = absdet * qw_data[qi] * grad_i.transpose() * grad_j
                local_mat_exprs.append(tmp[0])
       
        local_mat_replacements, local_mat_reduced_exprs = sp.cse(exprs=local_mat_exprs,symbols=numbered_symbols(prefix="w{w}_tmpcse_local_mat_"))
        kernel += local_mat_replacements
        local_matrix = sp.Matrix(num_nodes_per_wedge, num_nodes_per_wedge, local_mat_reduced_exprs)
        dst_wedge_rhss = local_matrix * srcs[w]
        dsts_wedge = [sp.symbols(f"dst_{w}_{i}") for i in range(num_nodes_per_wedge)]
        for dst, dst_rhs in zip(dsts_wedge, dst_wedge_rhss):
            kernel.append((dst, dst_rhs))
        dsts += dsts_wedge
       
kernel += print_atomic_add_local_wedge_scalar_coefficients(local_subdomain_id, x_cell, y_cell, r_cell, dsts)

# Finally: print code
cpp_code = "\n// Kernel body:\n"
for stmt in kernel:
    #print(var_name)
    #print(expr)
    if isinstance(stmt, str):
        cpp_code += stmt
    else:
        var_name, expr = stmt
        if isinstance(expr, str):
            cpp_code += f"double {var_name} = {expr};\n"
        else:
            cpp_code += f"double {var_name} = {ccode(expr)};\n"
print(cpp_code)
#print(print_atomic_add_local_wedge_scalar_coefficients())
# Out:
# // Kernel body:
# double quad_surface_coords_0_0_0 = lateral_grid(local_subdomain_id,0,0,0);
# double quad_surface_coords_0_0_1 = lateral_grid(local_subdomain_id,0,0,1);
# double quad_surface_coords_0_0_2 = lateral_grid(local_subdomain_id,0,0,2);
# double quad_surface_coords_0_1_0 = lateral_grid(local_subdomain_id,0,1,0);
# double quad_surface_coords_0_1_1 = lateral_grid(local_subdomain_id,0,1,1);
# double quad_surface_coords_0_1_2 = lateral_grid(local_subdomain_id,0,1,2);
# double quad_surface_coords_1_0_0 = lateral_grid(local_subdomain_id,1,0,0);
# double quad_surface_coords_1_0_1 = lateral_grid(local_subdomain_id,1,0,1);
# double quad_surface_coords_1_0_2 = lateral_grid(local_subdomain_id,1,0,2);
# double quad_surface_coords_1_1_0 = lateral_grid(local_subdomain_id,1,1,0);
# double quad_surface_coords_1_1_1 = lateral_grid(local_subdomain_id,1,1,1);
# double quad_surface_coords_1_1_2 = lateral_grid(local_subdomain_id,1,1,2);
# double wedge_surf_phy_coords_0_0_0 = quad_surface_coords_0_0_0;
# double wedge_surf_phy_coords_0_0_1 = quad_surface_coords_0_0_1;
# double wedge_surf_phy_coords_0_0_2 = quad_surface_coords_0_0_2;
# double wedge_surf_phy_coords_0_1_0 = quad_surface_coords_1_0_0;
# double wedge_surf_phy_coords_0_1_1 = quad_surface_coords_1_0_1;
# double wedge_surf_phy_coords_0_1_2 = quad_surface_coords_1_0_2;
# double wedge_surf_phy_coords_0_2_0 = quad_surface_coords_0_1_0;
# double wedge_surf_phy_coords_0_2_1 = quad_surface_coords_0_1_1;
# double wedge_surf_phy_coords_0_2_2 = quad_surface_coords_0_1_2;
# double wedge_surf_phy_coords_1_0_0 = quad_surface_coords_1_1_0;
# double wedge_surf_phy_coords_1_0_1 = quad_surface_coords_1_1_1;
# double wedge_surf_phy_coords_1_0_2 = quad_surface_coords_1_1_2;
# double wedge_surf_phy_coords_1_1_0 = quad_surface_coords_0_1_0;
# double wedge_surf_phy_coords_1_1_1 = quad_surface_coords_0_1_1;
# double wedge_surf_phy_coords_1_1_2 = quad_surface_coords_0_1_2;
# double wedge_surf_phy_coords_1_2_0 = quad_surface_coords_1_0_0;
# double wedge_surf_phy_coords_1_2_1 = quad_surface_coords_1_0_1;
# double wedge_surf_phy_coords_1_2_2 = quad_surface_coords_1_0_2;
# double r_0 = radii_(local_subdomain_id, r_cell);
# double r_1 = radii_(local_subdomain_id, r_cell);
# double qp_0_0 = 0.33333333333333331;
# double qp_0_1 = 0.33333333333333331;
# double qp_0_2 = 0.0;
# double qw_0 = 1.0;
# double src_0_0 = src_(local_subdomain_id,x_cell,y_cell,r_cell);
# double src_0_1 = src_(local_subdomain_id,x_cell + 1,y_cell,r_cell);
# double src_0_2 = src_(local_subdomain_id,x_cell,y_cell + 1,r_cell);
# double src_0_3 = src_(local_subdomain_id,x_cell,y_cell,r_cell + 1);
# double src_0_4 = src_(local_subdomain_id,x_cell + 1,y_cell,r_cell + 1);
# double src_0_5 = src_(local_subdomain_id,x_cell,y_cell + 1,r_cell + 1);
# double src_1_0 = src_(local_subdomain_id,x_cell + 1,y_cell + 1,r_cell);
# double src_1_1 = src_(local_subdomain_id,x_cell,y_cell + 1,r_cell);
# double src_1_2 = src_(local_subdomain_id,x_cell + 1,y_cell,r_cell);
# double src_1_3 = src_(local_subdomain_id,x_cell + 1,y_cell + 1,r_cell + 1);
# double src_1_4 = src_(local_subdomain_id,x_cell,y_cell + 1,r_cell + 1);
# double src_1_5 = src_(local_subdomain_id,x_cell + 1,y_cell,r_cell + 1);
# double w0_tmpcse_J_0 = 0.5*r_0 + 0.5*r_1;
# double w0_tmpcse_J_1 = -1.0/2.0*r_0 + (1.0/2.0)*r_1;
# double w0_J_0_0 = w0_tmpcse_J_0*(-wedge_surf_phy_coords_0_0_0 + wedge_surf_phy_coords_0_1_0);
# double w0_J_0_1 = w0_tmpcse_J_0*(-wedge_surf_phy_coords_0_0_0 + wedge_surf_phy_coords_0_2_0);
# double w0_J_0_2 = w0_tmpcse_J_1*(0.33333333333333343*wedge_surf_phy_coords_0_0_0 + 0.33333333333333331*wedge_surf_phy_coords_0_1_0 + 0.33333333333333331*wedge_surf_phy_coords_0_2_0);
# double w0_J_1_0 = w0_tmpcse_J_0*(-wedge_surf_phy_coords_0_0_1 + wedge_surf_phy_coords_0_1_1);
# double w0_J_1_1 = w0_tmpcse_J_0*(-wedge_surf_phy_coords_0_0_1 + wedge_surf_phy_coords_0_2_1);
# double w0_J_1_2 = w0_tmpcse_J_1*(0.33333333333333343*wedge_surf_phy_coords_0_0_1 + 0.33333333333333331*wedge_surf_phy_coords_0_1_1 + 0.33333333333333331*wedge_surf_phy_coords_0_2_1);
# double w0_J_2_0 = w0_tmpcse_J_0*(-wedge_surf_phy_coords_0_0_2 + wedge_surf_phy_coords_0_1_2);
# double w0_J_2_1 = w0_tmpcse_J_0*(-wedge_surf_phy_coords_0_0_2 + wedge_surf_phy_coords_0_2_2);
# double w0_J_2_2 = w0_tmpcse_J_1*(0.33333333333333343*wedge_surf_phy_coords_0_0_2 + 0.33333333333333331*wedge_surf_phy_coords_0_1_2 + 0.33333333333333331*wedge_surf_phy_coords_0_2_2);
# double w0_tmpcse_J_invT_0 = w0_J_1_1*w0_J_2_2;
# double w0_tmpcse_J_invT_1 = w0_J_1_2*w0_J_2_1;
# double w0_tmpcse_J_invT_2 = w0_J_1_0*w0_J_2_1;
# double w0_tmpcse_J_invT_3 = w0_J_1_0*w0_J_2_2;
# double w0_tmpcse_J_invT_4 = w0_J_1_1*w0_J_2_0;
# double w0_tmpcse_J_invT_5 = 1.0/(w0_J_0_0*w0_tmpcse_J_invT_0 - w0_J_0_0*w0_tmpcse_J_invT_1 + w0_J_0_1*w0_J_1_2*w0_J_2_0 - w0_J_0_1*w0_tmpcse_J_invT_3 + w0_J_0_2*w0_tmpcse_J_invT_2 - w0_J_0_2*w0_tmpcse_J_invT_4);
# double w0_J_invT_cse_0_0 = w0_tmpcse_J_invT_5*(w0_tmpcse_J_invT_0 - w0_tmpcse_J_invT_1);
# double w0_J_invT_cse_0_1 = w0_tmpcse_J_invT_5*(w0_J_1_2*w0_J_2_0 - w0_tmpcse_J_invT_3);
# double w0_J_invT_cse_0_2 = w0_tmpcse_J_invT_5*(w0_tmpcse_J_invT_2 - w0_tmpcse_J_invT_4);
# double w0_J_invT_cse_1_0 = w0_tmpcse_J_invT_5*(-w0_J_0_1*w0_J_2_2 + w0_J_0_2*w0_J_2_1);
# double w0_J_invT_cse_1_1 = w0_tmpcse_J_invT_5*(w0_J_0_0*w0_J_2_2 - w0_J_0_2*w0_J_2_0);
# double w0_J_invT_cse_1_2 = w0_tmpcse_J_invT_5*(-w0_J_0_0*w0_J_2_1 + w0_J_0_1*w0_J_2_0);
# double w0_J_invT_cse_2_0 = w0_tmpcse_J_invT_5*(w0_J_0_1*w0_J_1_2 - w0_J_0_2*w0_J_1_1);
# double w0_J_invT_cse_2_1 = w0_tmpcse_J_invT_5*(-w0_J_0_0*w0_J_1_2 + w0_J_0_2*w0_J_1_0);
# double w0_J_invT_cse_2_2 = w0_tmpcse_J_invT_5*(w0_J_0_0*w0_J_1_1 - w0_J_0_1*w0_J_1_0);
# double absdet = fabs(w0_J_0_0*w0_J_1_1*w0_J_2_2 - w0_J_0_0*w0_J_1_2*w0_J_2_1 - w0_J_0_1*w0_J_1_0*w0_J_2_2 + w0_J_0_1*w0_J_1_2*w0_J_2_0 + w0_J_0_2*w0_J_1_0*w0_J_2_1 - w0_J_0_2*w0_J_1_1*w0_J_2_0);
# double w{w}_tmpcse_local_mat_0 = w0_tmpcse_J_invT_2 - w0_tmpcse_J_invT_4;
# double w{w}_tmpcse_local_mat_1 = 0.33333333333333343*w0_tmpcse_J_invT_5;
# double w{w}_tmpcse_local_mat_2 = w{w}_tmpcse_local_mat_0*w{w}_tmpcse_local_mat_1;
# double w{w}_tmpcse_local_mat_3 = w0_tmpcse_J_invT_5*(w0_tmpcse_J_invT_0 - w0_tmpcse_J_invT_1);
# double w{w}_tmpcse_local_mat_4 = w0_tmpcse_J_invT_5*(w0_J_1_2*w0_J_2_0 - w0_tmpcse_J_invT_3);
# double w{w}_tmpcse_local_mat_5 = w{w}_tmpcse_local_mat_3 + w{w}_tmpcse_local_mat_4;
# double w{w}_tmpcse_local_mat_6 = w0_J_0_0*w0_J_1_1 - w0_J_0_1*w0_J_1_0;
# double w{w}_tmpcse_local_mat_7 = w{w}_tmpcse_local_mat_1*w{w}_tmpcse_local_mat_6;
# double w{w}_tmpcse_local_mat_8 = w0_tmpcse_J_invT_5*(w0_J_0_1*w0_J_1_2 - w0_J_0_2*w0_J_1_1);
# double w{w}_tmpcse_local_mat_9 = w0_tmpcse_J_invT_5*(-w0_J_0_0*w0_J_1_2 + w0_J_0_2*w0_J_1_0);
# double w{w}_tmpcse_local_mat_10 = w{w}_tmpcse_local_mat_8 + w{w}_tmpcse_local_mat_9;
# double w{w}_tmpcse_local_mat_11 = -w0_J_0_0*w0_J_2_1 + w0_J_0_1*w0_J_2_0;
# double w{w}_tmpcse_local_mat_12 = w{w}_tmpcse_local_mat_1*w{w}_tmpcse_local_mat_11;
# double w{w}_tmpcse_local_mat_13 = w0_tmpcse_J_invT_5*(-w0_J_0_1*w0_J_2_2 + w0_J_0_2*w0_J_2_1);
# double w{w}_tmpcse_local_mat_14 = w0_tmpcse_J_invT_5*(w0_J_0_0*w0_J_2_2 - w0_J_0_2*w0_J_2_0);
# double w{w}_tmpcse_local_mat_15 = w{w}_tmpcse_local_mat_13 + w{w}_tmpcse_local_mat_14;
# double w{w}_tmpcse_local_mat_16 = 0.5*w{w}_tmpcse_local_mat_3;
# double w{w}_tmpcse_local_mat_17 = w0_tmpcse_J_invT_5*w{w}_tmpcse_local_mat_0;
# double w{w}_tmpcse_local_mat_18 = 0.16666666666666666*w{w}_tmpcse_local_mat_17;
# double w{w}_tmpcse_local_mat_19 = w{w}_tmpcse_local_mat_16 - w{w}_tmpcse_local_mat_18;
# double w{w}_tmpcse_local_mat_20 = 0.16666666666666671*w{w}_tmpcse_local_mat_17;
# double w{w}_tmpcse_local_mat_21 = 0.5*w{w}_tmpcse_local_mat_4;
# double w{w}_tmpcse_local_mat_22 = w{w}_tmpcse_local_mat_16 + w{w}_tmpcse_local_mat_21;
# double w{w}_tmpcse_local_mat_23 = 1.0*absdet;
# double w{w}_tmpcse_local_mat_24 = w{w}_tmpcse_local_mat_23*(-w{w}_tmpcse_local_mat_20 - w{w}_tmpcse_local_mat_22);
# double w{w}_tmpcse_local_mat_25 = w0_tmpcse_J_invT_5*w{w}_tmpcse_local_mat_6;
# double w{w}_tmpcse_local_mat_26 = 0.16666666666666666*w{w}_tmpcse_local_mat_25;
# double w{w}_tmpcse_local_mat_27 = 0.5*w{w}_tmpcse_local_mat_8;
# double w{w}_tmpcse_local_mat_28 = -w{w}_tmpcse_local_mat_26 + w{w}_tmpcse_local_mat_27;
# double w{w}_tmpcse_local_mat_29 = 0.16666666666666671*w{w}_tmpcse_local_mat_25;
# double w{w}_tmpcse_local_mat_30 = 0.5*w{w}_tmpcse_local_mat_9;
# double w{w}_tmpcse_local_mat_31 = w{w}_tmpcse_local_mat_27 + w{w}_tmpcse_local_mat_30;
# double w{w}_tmpcse_local_mat_32 = w{w}_tmpcse_local_mat_23*(-w{w}_tmpcse_local_mat_29 - w{w}_tmpcse_local_mat_31);
# double w{w}_tmpcse_local_mat_33 = w0_tmpcse_J_invT_5*w{w}_tmpcse_local_mat_11;
# double w{w}_tmpcse_local_mat_34 = 0.16666666666666666*w{w}_tmpcse_local_mat_33;
# double w{w}_tmpcse_local_mat_35 = 0.5*w{w}_tmpcse_local_mat_13;
# double w{w}_tmpcse_local_mat_36 = -w{w}_tmpcse_local_mat_34 + w{w}_tmpcse_local_mat_35;
# double w{w}_tmpcse_local_mat_37 = 0.16666666666666671*w{w}_tmpcse_local_mat_33;
# double w{w}_tmpcse_local_mat_38 = 0.5*w{w}_tmpcse_local_mat_14;
# double w{w}_tmpcse_local_mat_39 = w{w}_tmpcse_local_mat_35 + w{w}_tmpcse_local_mat_38;
# double w{w}_tmpcse_local_mat_40 = w{w}_tmpcse_local_mat_23*(-w{w}_tmpcse_local_mat_37 - w{w}_tmpcse_local_mat_39);
# double w{w}_tmpcse_local_mat_41 = w{w}_tmpcse_local_mat_19*w{w}_tmpcse_local_mat_24 + w{w}_tmpcse_local_mat_28*w{w}_tmpcse_local_mat_32 + w{w}_tmpcse_local_mat_36*w{w}_tmpcse_local_mat_40;
# double w{w}_tmpcse_local_mat_42 = -w{w}_tmpcse_local_mat_18 + w{w}_tmpcse_local_mat_21;
# double w{w}_tmpcse_local_mat_43 = -w{w}_tmpcse_local_mat_26 + w{w}_tmpcse_local_mat_30;
# double w{w}_tmpcse_local_mat_44 = -w{w}_tmpcse_local_mat_34 + w{w}_tmpcse_local_mat_38;
# double w{w}_tmpcse_local_mat_45 = w{w}_tmpcse_local_mat_24*w{w}_tmpcse_local_mat_42 + w{w}_tmpcse_local_mat_32*w{w}_tmpcse_local_mat_43 + w{w}_tmpcse_local_mat_40*w{w}_tmpcse_local_mat_44;
# double w{w}_tmpcse_local_mat_46 = w{w}_tmpcse_local_mat_20 - w{w}_tmpcse_local_mat_22;
# double w{w}_tmpcse_local_mat_47 = w{w}_tmpcse_local_mat_29 - w{w}_tmpcse_local_mat_31;
# double w{w}_tmpcse_local_mat_48 = w{w}_tmpcse_local_mat_37 - w{w}_tmpcse_local_mat_39;
# double w{w}_tmpcse_local_mat_49 = w{w}_tmpcse_local_mat_24*w{w}_tmpcse_local_mat_46 + w{w}_tmpcse_local_mat_32*w{w}_tmpcse_local_mat_47 + w{w}_tmpcse_local_mat_40*w{w}_tmpcse_local_mat_48;
# double w{w}_tmpcse_local_mat_50 = w{w}_tmpcse_local_mat_16 + w{w}_tmpcse_local_mat_18;
# double w{w}_tmpcse_local_mat_51 = w{w}_tmpcse_local_mat_26 + w{w}_tmpcse_local_mat_27;
# double w{w}_tmpcse_local_mat_52 = w{w}_tmpcse_local_mat_34 + w{w}_tmpcse_local_mat_35;
# double w{w}_tmpcse_local_mat_53 = w{w}_tmpcse_local_mat_24*w{w}_tmpcse_local_mat_50 + w{w}_tmpcse_local_mat_32*w{w}_tmpcse_local_mat_51 + w{w}_tmpcse_local_mat_40*w{w}_tmpcse_local_mat_52;
# double w{w}_tmpcse_local_mat_54 = w{w}_tmpcse_local_mat_18 + w{w}_tmpcse_local_mat_21;
# double w{w}_tmpcse_local_mat_55 = w{w}_tmpcse_local_mat_26 + w{w}_tmpcse_local_mat_30;
# double w{w}_tmpcse_local_mat_56 = w{w}_tmpcse_local_mat_34 + w{w}_tmpcse_local_mat_38;
# double w{w}_tmpcse_local_mat_57 = w{w}_tmpcse_local_mat_24*w{w}_tmpcse_local_mat_54 + w{w}_tmpcse_local_mat_32*w{w}_tmpcse_local_mat_55 + w{w}_tmpcse_local_mat_40*w{w}_tmpcse_local_mat_56;
# double w{w}_tmpcse_local_mat_58 = 0.33333333333333331*w{w}_tmpcse_local_mat_17;
# double w{w}_tmpcse_local_mat_59 = 0.33333333333333331*w{w}_tmpcse_local_mat_25;
# double w{w}_tmpcse_local_mat_60 = 0.33333333333333331*w{w}_tmpcse_local_mat_33;
# double w{w}_tmpcse_local_mat_61 = w{w}_tmpcse_local_mat_19*w{w}_tmpcse_local_mat_23;
# double w{w}_tmpcse_local_mat_62 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_28;
# double w{w}_tmpcse_local_mat_63 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_36;
# double w{w}_tmpcse_local_mat_64 = w{w}_tmpcse_local_mat_42*w{w}_tmpcse_local_mat_61 + w{w}_tmpcse_local_mat_43*w{w}_tmpcse_local_mat_62 + w{w}_tmpcse_local_mat_44*w{w}_tmpcse_local_mat_63;
# double w{w}_tmpcse_local_mat_65 = w{w}_tmpcse_local_mat_46*w{w}_tmpcse_local_mat_61 + w{w}_tmpcse_local_mat_47*w{w}_tmpcse_local_mat_62 + w{w}_tmpcse_local_mat_48*w{w}_tmpcse_local_mat_63;
# double w{w}_tmpcse_local_mat_66 = w{w}_tmpcse_local_mat_50*w{w}_tmpcse_local_mat_61 + w{w}_tmpcse_local_mat_51*w{w}_tmpcse_local_mat_62 + w{w}_tmpcse_local_mat_52*w{w}_tmpcse_local_mat_63;
# double w{w}_tmpcse_local_mat_67 = w{w}_tmpcse_local_mat_54*w{w}_tmpcse_local_mat_61 + w{w}_tmpcse_local_mat_55*w{w}_tmpcse_local_mat_62 + w{w}_tmpcse_local_mat_56*w{w}_tmpcse_local_mat_63;
# double w{w}_tmpcse_local_mat_68 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_42;
# double w{w}_tmpcse_local_mat_69 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_43;
# double w{w}_tmpcse_local_mat_70 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_44;
# double w{w}_tmpcse_local_mat_71 = w{w}_tmpcse_local_mat_46*w{w}_tmpcse_local_mat_68 + w{w}_tmpcse_local_mat_47*w{w}_tmpcse_local_mat_69 + w{w}_tmpcse_local_mat_48*w{w}_tmpcse_local_mat_70;
# double w{w}_tmpcse_local_mat_72 = w{w}_tmpcse_local_mat_50*w{w}_tmpcse_local_mat_68 + w{w}_tmpcse_local_mat_51*w{w}_tmpcse_local_mat_69 + w{w}_tmpcse_local_mat_52*w{w}_tmpcse_local_mat_70;
# double w{w}_tmpcse_local_mat_73 = w{w}_tmpcse_local_mat_54*w{w}_tmpcse_local_mat_68 + w{w}_tmpcse_local_mat_55*w{w}_tmpcse_local_mat_69 + w{w}_tmpcse_local_mat_56*w{w}_tmpcse_local_mat_70;
# double w{w}_tmpcse_local_mat_74 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_46;
# double w{w}_tmpcse_local_mat_75 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_47;
# double w{w}_tmpcse_local_mat_76 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_48;
# double w{w}_tmpcse_local_mat_77 = w{w}_tmpcse_local_mat_50*w{w}_tmpcse_local_mat_74 + w{w}_tmpcse_local_mat_51*w{w}_tmpcse_local_mat_75 + w{w}_tmpcse_local_mat_52*w{w}_tmpcse_local_mat_76;
# double w{w}_tmpcse_local_mat_78 = w{w}_tmpcse_local_mat_54*w{w}_tmpcse_local_mat_74 + w{w}_tmpcse_local_mat_55*w{w}_tmpcse_local_mat_75 + w{w}_tmpcse_local_mat_56*w{w}_tmpcse_local_mat_76;
# double w{w}_tmpcse_local_mat_79 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_50*w{w}_tmpcse_local_mat_54 + w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_51*w{w}_tmpcse_local_mat_55 + w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_52*w{w}_tmpcse_local_mat_56;
# double dst_0_0 = src_0_0*(0.25*absdet*pow(-w{w}_tmpcse_local_mat_10 - w{w}_tmpcse_local_mat_7, 2) + 0.25*absdet*pow(-w{w}_tmpcse_local_mat_12 - w{w}_tmpcse_local_mat_15, 2) + 0.25*absdet*pow(-w{w}_tmpcse_local_mat_2 - w{w}_tmpcse_local_mat_5, 2));
# double dst_0_1 = src_0_0*w{w}_tmpcse_local_mat_41;
# double dst_0_2 = src_0_0*w{w}_tmpcse_local_mat_45;
# double dst_0_3 = src_0_0*w{w}_tmpcse_local_mat_49;
# double dst_0_4 = src_0_0*w{w}_tmpcse_local_mat_53;
# double dst_0_5 = src_0_0*w{w}_tmpcse_local_mat_57;
# double w1_tmpcse_J_0 = 0.5*r_0 + 0.5*r_1;
# double w1_tmpcse_J_1 = -1.0/2.0*r_0 + (1.0/2.0)*r_1;
# double w1_J_0_0 = w1_tmpcse_J_0*(-wedge_surf_phy_coords_1_0_0 + wedge_surf_phy_coords_1_1_0);
# double w1_J_0_1 = w1_tmpcse_J_0*(-wedge_surf_phy_coords_1_0_0 + wedge_surf_phy_coords_1_2_0);
# double w1_J_0_2 = w1_tmpcse_J_1*(0.33333333333333343*wedge_surf_phy_coords_1_0_0 + 0.33333333333333331*wedge_surf_phy_coords_1_1_0 + 0.33333333333333331*wedge_surf_phy_coords_1_2_0);
# double w1_J_1_0 = w1_tmpcse_J_0*(-wedge_surf_phy_coords_1_0_1 + wedge_surf_phy_coords_1_1_1);
# double w1_J_1_1 = w1_tmpcse_J_0*(-wedge_surf_phy_coords_1_0_1 + wedge_surf_phy_coords_1_2_1);
# double w1_J_1_2 = w1_tmpcse_J_1*(0.33333333333333343*wedge_surf_phy_coords_1_0_1 + 0.33333333333333331*wedge_surf_phy_coords_1_1_1 + 0.33333333333333331*wedge_surf_phy_coords_1_2_1);
# double w1_J_2_0 = w1_tmpcse_J_0*(-wedge_surf_phy_coords_1_0_2 + wedge_surf_phy_coords_1_1_2);
# double w1_J_2_1 = w1_tmpcse_J_0*(-wedge_surf_phy_coords_1_0_2 + wedge_surf_phy_coords_1_2_2);
# double w1_J_2_2 = w1_tmpcse_J_1*(0.33333333333333343*wedge_surf_phy_coords_1_0_2 + 0.33333333333333331*wedge_surf_phy_coords_1_1_2 + 0.33333333333333331*wedge_surf_phy_coords_1_2_2);
# double w1_tmpcse_J_invT_0 = w1_J_1_1*w1_J_2_2;
# double w1_tmpcse_J_invT_1 = w1_J_1_2*w1_J_2_1;
# double w1_tmpcse_J_invT_2 = w1_J_1_0*w1_J_2_1;
# double w1_tmpcse_J_invT_3 = w1_J_1_0*w1_J_2_2;
# double w1_tmpcse_J_invT_4 = w1_J_1_1*w1_J_2_0;
# double w1_tmpcse_J_invT_5 = 1.0/(w1_J_0_0*w1_tmpcse_J_invT_0 - w1_J_0_0*w1_tmpcse_J_invT_1 + w1_J_0_1*w1_J_1_2*w1_J_2_0 - w1_J_0_1*w1_tmpcse_J_invT_3 + w1_J_0_2*w1_tmpcse_J_invT_2 - w1_J_0_2*w1_tmpcse_J_invT_4);
# double w1_J_invT_cse_0_0 = w1_tmpcse_J_invT_5*(w1_tmpcse_J_invT_0 - w1_tmpcse_J_invT_1);
# double w1_J_invT_cse_0_1 = w1_tmpcse_J_invT_5*(w1_J_1_2*w1_J_2_0 - w1_tmpcse_J_invT_3);
# double w1_J_invT_cse_0_2 = w1_tmpcse_J_invT_5*(w1_tmpcse_J_invT_2 - w1_tmpcse_J_invT_4);
# double w1_J_invT_cse_1_0 = w1_tmpcse_J_invT_5*(-w1_J_0_1*w1_J_2_2 + w1_J_0_2*w1_J_2_1);
# double w1_J_invT_cse_1_1 = w1_tmpcse_J_invT_5*(w1_J_0_0*w1_J_2_2 - w1_J_0_2*w1_J_2_0);
# double w1_J_invT_cse_1_2 = w1_tmpcse_J_invT_5*(-w1_J_0_0*w1_J_2_1 + w1_J_0_1*w1_J_2_0);
# double w1_J_invT_cse_2_0 = w1_tmpcse_J_invT_5*(w1_J_0_1*w1_J_1_2 - w1_J_0_2*w1_J_1_1);
# double w1_J_invT_cse_2_1 = w1_tmpcse_J_invT_5*(-w1_J_0_0*w1_J_1_2 + w1_J_0_2*w1_J_1_0);
# double w1_J_invT_cse_2_2 = w1_tmpcse_J_invT_5*(w1_J_0_0*w1_J_1_1 - w1_J_0_1*w1_J_1_0);
# double absdet = fabs(w1_J_0_0*w1_J_1_1*w1_J_2_2 - w1_J_0_0*w1_J_1_2*w1_J_2_1 - w1_J_0_1*w1_J_1_0*w1_J_2_2 + w1_J_0_1*w1_J_1_2*w1_J_2_0 + w1_J_0_2*w1_J_1_0*w1_J_2_1 - w1_J_0_2*w1_J_1_1*w1_J_2_0);
# double w{w}_tmpcse_local_mat_0 = w1_tmpcse_J_invT_2 - w1_tmpcse_J_invT_4;
# double w{w}_tmpcse_local_mat_1 = 0.33333333333333343*w1_tmpcse_J_invT_5;
# double w{w}_tmpcse_local_mat_2 = w{w}_tmpcse_local_mat_0*w{w}_tmpcse_local_mat_1;
# double w{w}_tmpcse_local_mat_3 = w1_tmpcse_J_invT_5*(w1_tmpcse_J_invT_0 - w1_tmpcse_J_invT_1);
# double w{w}_tmpcse_local_mat_4 = w1_tmpcse_J_invT_5*(w1_J_1_2*w1_J_2_0 - w1_tmpcse_J_invT_3);
# double w{w}_tmpcse_local_mat_5 = w{w}_tmpcse_local_mat_3 + w{w}_tmpcse_local_mat_4;
# double w{w}_tmpcse_local_mat_6 = w1_J_0_0*w1_J_1_1 - w1_J_0_1*w1_J_1_0;
# double w{w}_tmpcse_local_mat_7 = w{w}_tmpcse_local_mat_1*w{w}_tmpcse_local_mat_6;
# double w{w}_tmpcse_local_mat_8 = w1_tmpcse_J_invT_5*(w1_J_0_1*w1_J_1_2 - w1_J_0_2*w1_J_1_1);
# double w{w}_tmpcse_local_mat_9 = w1_tmpcse_J_invT_5*(-w1_J_0_0*w1_J_1_2 + w1_J_0_2*w1_J_1_0);
# double w{w}_tmpcse_local_mat_10 = w{w}_tmpcse_local_mat_8 + w{w}_tmpcse_local_mat_9;
# double w{w}_tmpcse_local_mat_11 = -w1_J_0_0*w1_J_2_1 + w1_J_0_1*w1_J_2_0;
# double w{w}_tmpcse_local_mat_12 = w{w}_tmpcse_local_mat_1*w{w}_tmpcse_local_mat_11;
# double w{w}_tmpcse_local_mat_13 = w1_tmpcse_J_invT_5*(-w1_J_0_1*w1_J_2_2 + w1_J_0_2*w1_J_2_1);
# double w{w}_tmpcse_local_mat_14 = w1_tmpcse_J_invT_5*(w1_J_0_0*w1_J_2_2 - w1_J_0_2*w1_J_2_0);
# double w{w}_tmpcse_local_mat_15 = w{w}_tmpcse_local_mat_13 + w{w}_tmpcse_local_mat_14;
# double w{w}_tmpcse_local_mat_16 = 0.5*w{w}_tmpcse_local_mat_3;
# double w{w}_tmpcse_local_mat_17 = w1_tmpcse_J_invT_5*w{w}_tmpcse_local_mat_0;
# double w{w}_tmpcse_local_mat_18 = 0.16666666666666666*w{w}_tmpcse_local_mat_17;
# double w{w}_tmpcse_local_mat_19 = w{w}_tmpcse_local_mat_16 - w{w}_tmpcse_local_mat_18;
# double w{w}_tmpcse_local_mat_20 = 0.16666666666666671*w{w}_tmpcse_local_mat_17;
# double w{w}_tmpcse_local_mat_21 = 0.5*w{w}_tmpcse_local_mat_4;
# double w{w}_tmpcse_local_mat_22 = w{w}_tmpcse_local_mat_16 + w{w}_tmpcse_local_mat_21;
# double w{w}_tmpcse_local_mat_23 = 1.0*absdet;
# double w{w}_tmpcse_local_mat_24 = w{w}_tmpcse_local_mat_23*(-w{w}_tmpcse_local_mat_20 - w{w}_tmpcse_local_mat_22);
# double w{w}_tmpcse_local_mat_25 = w1_tmpcse_J_invT_5*w{w}_tmpcse_local_mat_6;
# double w{w}_tmpcse_local_mat_26 = 0.16666666666666666*w{w}_tmpcse_local_mat_25;
# double w{w}_tmpcse_local_mat_27 = 0.5*w{w}_tmpcse_local_mat_8;
# double w{w}_tmpcse_local_mat_28 = -w{w}_tmpcse_local_mat_26 + w{w}_tmpcse_local_mat_27;
# double w{w}_tmpcse_local_mat_29 = 0.16666666666666671*w{w}_tmpcse_local_mat_25;
# double w{w}_tmpcse_local_mat_30 = 0.5*w{w}_tmpcse_local_mat_9;
# double w{w}_tmpcse_local_mat_31 = w{w}_tmpcse_local_mat_27 + w{w}_tmpcse_local_mat_30;
# double w{w}_tmpcse_local_mat_32 = w{w}_tmpcse_local_mat_23*(-w{w}_tmpcse_local_mat_29 - w{w}_tmpcse_local_mat_31);
# double w{w}_tmpcse_local_mat_33 = w1_tmpcse_J_invT_5*w{w}_tmpcse_local_mat_11;
# double w{w}_tmpcse_local_mat_34 = 0.16666666666666666*w{w}_tmpcse_local_mat_33;
# double w{w}_tmpcse_local_mat_35 = 0.5*w{w}_tmpcse_local_mat_13;
# double w{w}_tmpcse_local_mat_36 = -w{w}_tmpcse_local_mat_34 + w{w}_tmpcse_local_mat_35;
# double w{w}_tmpcse_local_mat_37 = 0.16666666666666671*w{w}_tmpcse_local_mat_33;
# double w{w}_tmpcse_local_mat_38 = 0.5*w{w}_tmpcse_local_mat_14;
# double w{w}_tmpcse_local_mat_39 = w{w}_tmpcse_local_mat_35 + w{w}_tmpcse_local_mat_38;
# double w{w}_tmpcse_local_mat_40 = w{w}_tmpcse_local_mat_23*(-w{w}_tmpcse_local_mat_37 - w{w}_tmpcse_local_mat_39);
# double w{w}_tmpcse_local_mat_41 = w{w}_tmpcse_local_mat_19*w{w}_tmpcse_local_mat_24 + w{w}_tmpcse_local_mat_28*w{w}_tmpcse_local_mat_32 + w{w}_tmpcse_local_mat_36*w{w}_tmpcse_local_mat_40;
# double w{w}_tmpcse_local_mat_42 = -w{w}_tmpcse_local_mat_18 + w{w}_tmpcse_local_mat_21;
# double w{w}_tmpcse_local_mat_43 = -w{w}_tmpcse_local_mat_26 + w{w}_tmpcse_local_mat_30;
# double w{w}_tmpcse_local_mat_44 = -w{w}_tmpcse_local_mat_34 + w{w}_tmpcse_local_mat_38;
# double w{w}_tmpcse_local_mat_45 = w{w}_tmpcse_local_mat_24*w{w}_tmpcse_local_mat_42 + w{w}_tmpcse_local_mat_32*w{w}_tmpcse_local_mat_43 + w{w}_tmpcse_local_mat_40*w{w}_tmpcse_local_mat_44;
# double w{w}_tmpcse_local_mat_46 = w{w}_tmpcse_local_mat_20 - w{w}_tmpcse_local_mat_22;
# double w{w}_tmpcse_local_mat_47 = w{w}_tmpcse_local_mat_29 - w{w}_tmpcse_local_mat_31;
# double w{w}_tmpcse_local_mat_48 = w{w}_tmpcse_local_mat_37 - w{w}_tmpcse_local_mat_39;
# double w{w}_tmpcse_local_mat_49 = w{w}_tmpcse_local_mat_24*w{w}_tmpcse_local_mat_46 + w{w}_tmpcse_local_mat_32*w{w}_tmpcse_local_mat_47 + w{w}_tmpcse_local_mat_40*w{w}_tmpcse_local_mat_48;
# double w{w}_tmpcse_local_mat_50 = w{w}_tmpcse_local_mat_16 + w{w}_tmpcse_local_mat_18;
# double w{w}_tmpcse_local_mat_51 = w{w}_tmpcse_local_mat_26 + w{w}_tmpcse_local_mat_27;
# double w{w}_tmpcse_local_mat_52 = w{w}_tmpcse_local_mat_34 + w{w}_tmpcse_local_mat_35;
# double w{w}_tmpcse_local_mat_53 = w{w}_tmpcse_local_mat_24*w{w}_tmpcse_local_mat_50 + w{w}_tmpcse_local_mat_32*w{w}_tmpcse_local_mat_51 + w{w}_tmpcse_local_mat_40*w{w}_tmpcse_local_mat_52;
# double w{w}_tmpcse_local_mat_54 = w{w}_tmpcse_local_mat_18 + w{w}_tmpcse_local_mat_21;
# double w{w}_tmpcse_local_mat_55 = w{w}_tmpcse_local_mat_26 + w{w}_tmpcse_local_mat_30;
# double w{w}_tmpcse_local_mat_56 = w{w}_tmpcse_local_mat_34 + w{w}_tmpcse_local_mat_38;
# double w{w}_tmpcse_local_mat_57 = w{w}_tmpcse_local_mat_24*w{w}_tmpcse_local_mat_54 + w{w}_tmpcse_local_mat_32*w{w}_tmpcse_local_mat_55 + w{w}_tmpcse_local_mat_40*w{w}_tmpcse_local_mat_56;
# double w{w}_tmpcse_local_mat_58 = 0.33333333333333331*w{w}_tmpcse_local_mat_17;
# double w{w}_tmpcse_local_mat_59 = 0.33333333333333331*w{w}_tmpcse_local_mat_25;
# double w{w}_tmpcse_local_mat_60 = 0.33333333333333331*w{w}_tmpcse_local_mat_33;
# double w{w}_tmpcse_local_mat_61 = w{w}_tmpcse_local_mat_19*w{w}_tmpcse_local_mat_23;
# double w{w}_tmpcse_local_mat_62 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_28;
# double w{w}_tmpcse_local_mat_63 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_36;
# double w{w}_tmpcse_local_mat_64 = w{w}_tmpcse_local_mat_42*w{w}_tmpcse_local_mat_61 + w{w}_tmpcse_local_mat_43*w{w}_tmpcse_local_mat_62 + w{w}_tmpcse_local_mat_44*w{w}_tmpcse_local_mat_63;
# double w{w}_tmpcse_local_mat_65 = w{w}_tmpcse_local_mat_46*w{w}_tmpcse_local_mat_61 + w{w}_tmpcse_local_mat_47*w{w}_tmpcse_local_mat_62 + w{w}_tmpcse_local_mat_48*w{w}_tmpcse_local_mat_63;
# double w{w}_tmpcse_local_mat_66 = w{w}_tmpcse_local_mat_50*w{w}_tmpcse_local_mat_61 + w{w}_tmpcse_local_mat_51*w{w}_tmpcse_local_mat_62 + w{w}_tmpcse_local_mat_52*w{w}_tmpcse_local_mat_63;
# double w{w}_tmpcse_local_mat_67 = w{w}_tmpcse_local_mat_54*w{w}_tmpcse_local_mat_61 + w{w}_tmpcse_local_mat_55*w{w}_tmpcse_local_mat_62 + w{w}_tmpcse_local_mat_56*w{w}_tmpcse_local_mat_63;
# double w{w}_tmpcse_local_mat_68 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_42;
# double w{w}_tmpcse_local_mat_69 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_43;
# double w{w}_tmpcse_local_mat_70 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_44;
# double w{w}_tmpcse_local_mat_71 = w{w}_tmpcse_local_mat_46*w{w}_tmpcse_local_mat_68 + w{w}_tmpcse_local_mat_47*w{w}_tmpcse_local_mat_69 + w{w}_tmpcse_local_mat_48*w{w}_tmpcse_local_mat_70;
# double w{w}_tmpcse_local_mat_72 = w{w}_tmpcse_local_mat_50*w{w}_tmpcse_local_mat_68 + w{w}_tmpcse_local_mat_51*w{w}_tmpcse_local_mat_69 + w{w}_tmpcse_local_mat_52*w{w}_tmpcse_local_mat_70;
# double w{w}_tmpcse_local_mat_73 = w{w}_tmpcse_local_mat_54*w{w}_tmpcse_local_mat_68 + w{w}_tmpcse_local_mat_55*w{w}_tmpcse_local_mat_69 + w{w}_tmpcse_local_mat_56*w{w}_tmpcse_local_mat_70;
# double w{w}_tmpcse_local_mat_74 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_46;
# double w{w}_tmpcse_local_mat_75 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_47;
# double w{w}_tmpcse_local_mat_76 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_48;
# double w{w}_tmpcse_local_mat_77 = w{w}_tmpcse_local_mat_50*w{w}_tmpcse_local_mat_74 + w{w}_tmpcse_local_mat_51*w{w}_tmpcse_local_mat_75 + w{w}_tmpcse_local_mat_52*w{w}_tmpcse_local_mat_76;
# double w{w}_tmpcse_local_mat_78 = w{w}_tmpcse_local_mat_54*w{w}_tmpcse_local_mat_74 + w{w}_tmpcse_local_mat_55*w{w}_tmpcse_local_mat_75 + w{w}_tmpcse_local_mat_56*w{w}_tmpcse_local_mat_76;
# double w{w}_tmpcse_local_mat_79 = w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_50*w{w}_tmpcse_local_mat_54 + w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_51*w{w}_tmpcse_local_mat_55 + w{w}_tmpcse_local_mat_23*w{w}_tmpcse_local_mat_52*w{w}_tmpcse_local_mat_56;
# double dst_1_0 = src_0_1*(0.25*absdet*pow(-w{w}_tmpcse_local_mat_10 - w{w}_tmpcse_local_mat_7, 2) + 0.25*absdet*pow(-w{w}_tmpcse_local_mat_12 - w{w}_tmpcse_local_mat_15, 2) + 0.25*absdet*pow(-w{w}_tmpcse_local_mat_2 - w{w}_tmpcse_local_mat_5, 2));
# double dst_1_1 = src_0_1*w{w}_tmpcse_local_mat_41;
# double dst_1_2 = src_0_1*w{w}_tmpcse_local_mat_45;
# double dst_1_3 = src_0_1*w{w}_tmpcse_local_mat_49;
# double dst_1_4 = src_0_1*w{w}_tmpcse_local_mat_53;
# double dst_1_5 = src_0_1*w{w}_tmpcse_local_mat_57;
# Kokkos::atomic_add(&dst_(local_subdomain_id, x_cell, y_cell, r_cell), dsts_0_0);
# Kokkos::atomic_add(&dst_(local_subdomain_id, x_cell + 1, y_cell, r_cell), dsts_0_1 + dsts_1_2);
# Kokkos::atomic_add(&dst_(local_subdomain_id, x_cell, y_cell + 1, r_cell), dsts_0_2 + dsts_1_1);
# Kokkos::atomic_add(&dst_(local_subdomain_id, x_cell, y_cell, r_cell + 1), dsts_0_3);
# Kokkos::atomic_add(&dst_(local_subdomain_id, x_cell + 1, y_cell, r_cell + 1), dsts_0_4 + dsts_1_5);
# Kokkos::atomic_add(&dst_(local_subdomain_id, x_cell, y_cell + 1, r_cell + 1), dsts_0_5 + dsts_1_4);
# Kokkos::atomic_add(&dst_(local_subdomain_id, x_cell + 1, y_cell + 1, r_cell), dsts_1_0);
# Kokkos::atomic_add(&dst_(local_subdomain_id, x_cell + 1, y_cell + 1, r_cell + 1), dsts_1_3);
